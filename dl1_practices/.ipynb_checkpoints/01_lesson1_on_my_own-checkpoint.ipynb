# %% [markdown]
# # Flower Classification

# %% [markdown]
# ## 1. Libraries

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

from fastai.vision import *
from fastai.metrics import error_rate
from scipy.io import loadmat

#bs = 64
bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %%
# GPU
import torch
torch.cuda.get_device_name(0)
# Out:
# 'Tesla P100-PCIE-16GB'

# %% [markdown]
# ## 2. Data

# %%
# Cogemos un dataset de la librería
path = untar_data(URLs.FLOWERS); path
# Out:
# PosixPath('/home/jupyter/.fastai/data/oxford-102-flowers')

# %%
path.ls()
# Out:
# [PosixPath('/home/jupyter/.fastai/data/oxford-102-flowers/valid.txt'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-102-flowers/test.txt'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-102-flowers/models'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-102-flowers/jpg'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-102-flowers/train.txt')]

# %%
# De esta forma se crea una lista con los archivos dentro de un path (path_img)
fnames = get_image_files(path/'jpg')
fnames[:5]
# Out:
# [PosixPath('/home/jupyter/.fastai/data/oxford-102-flowers/jpg/image_03449.jpg'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-102-flowers/jpg/image_05274.jpg'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-102-flowers/jpg/image_03731.jpg'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-102-flowers/jpg/image_07311.jpg'),
#  PosixPath('/home/jupyter/.fastai/data/oxford-102-flowers/jpg/image_05189.jpg')]

# %% [markdown]
# ### 2.1 From txt to DataFrame

# %%
train = pd.read_csv(path/'train.txt',sep=' ', header= None)
train.columns=['Img', 'Class']
train.head()
# Out:
#                    Img  Class
# 0  jpg/image_03860.jpg     16
# 1  jpg/image_06092.jpg     13
# 2  jpg/image_02400.jpg     42
# 3  jpg/image_02852.jpg     55
# 4  jpg/image_07710.jpg     96

# %%
test = pd.read_csv(path/'test.txt',sep=' ', header= None)
test.columns=['Img', 'Class']
test.head()
# Out:
#                    Img  Class
# 0  jpg/image_06977.jpg     34
# 1  jpg/image_00800.jpg     80
# 2  jpg/image_05038.jpg     58
# 3  jpg/image_06759.jpg      0
# 4  jpg/image_01133.jpg     45

# %%
valid = pd.read_csv(path/'valid.txt', sep=' ', header= None)
valid.columns=['Img', 'Class']
valid.head()
# Out:
#                    Img  Class
# 0  jpg/image_04467.jpg     89
# 1  jpg/image_07129.jpg     44
# 2  jpg/image_05166.jpg      4
# 3  jpg/image_07002.jpg     34
# 4  jpg/image_02007.jpg     79

# %%
df = train.append(valid, ignore_index=True).append(test, ignore_index=True)
df.columns=['Img', 'Class']
df.index = df['Img']
df.head()
# Out:
#                                      Img  Class
# Img
# jpg/image_03860.jpg  jpg/image_03860.jpg     16
# jpg/image_06092.jpg  jpg/image_06092.jpg     13
# jpg/image_02400.jpg  jpg/image_02400.jpg     42
# jpg/image_02852.jpg  jpg/image_02852.jpg     55
# jpg/image_07710.jpg  jpg/image_07710.jpg     96

# %%
len(train), len(valid), len(test)
# Out:
# (1020, 1020, 6149)

# %% [markdown]
# ### 2.2 Classes Names

# %%
labels = pd.read_csv('https://gist.githubusercontent.com/JosephKJ/94c7728ed1a8e0cd87fe6a029769cde1/raw/403325f5110cb0f3099734c5edb9f457539c77e9/Oxford-102_Flower_dataset_labels.txt', header=None)
labels.rename(columns={0:'label'},inplace=True)
labels['label'] = labels['label'].apply(lambda x: x.rstrip("\'").replace("\'",""))

# %%
df.merge(labels,left_on='Class',right_index=True)
train = train.merge(labels,left_on='Class',right_index=True)
test = test.merge(labels,left_on='Class',right_index=True)
valid =valid.merge(labels,left_on='Class',right_index=True)

# %%
df.drop(columns='Class',inplace=True)
train.drop(columns='Class',inplace=True)
test.drop(columns='Class',inplace=True)
valid.drop(columns='Class',inplace=True)

# %%
valid.head()
# Out:
#                      Img        label
# 0    jpg/image_04467.jpg   canna lily
# 52   jpg/image_04440.jpg   canna lily
# 157  jpg/image_04408.jpg   canna lily
# 252  jpg/image_04479.jpg   canna lily
# 415  jpg/image_04429.jpg   canna lily

# %% [markdown]
# ### 2.3 Show Images

# %%
# Show a single Image
img_f = fnames[4]
img = open_image(img_f)
img.show(figsize=(5,5))

# %% [markdown]
# ### 2.4 Databunch

# %%
# Size
src_size = min(img.size)
size = src_size

trainList = ImageList.from_df(df=train, path=path)
validList = ImageList.from_df(df=valid, path=path)
testList = ImageList.from_df(df=test, path=path)

src = (ImageList.from_folder(path)
       .split_by_list(trainList, validList)
       .label_from_df()
       )

data = (src.transform(get_transforms(), size=size)
        .databunch(bs=bs)
        .normalize(imagenet_stats))

# Another way to get this

# tfms = get_transforms()
# data = (ImageList.from_df(df, path)
#                  .split_from_df()
#                  .label_from_df()
#                  .transform(tfms, size=64)
#                  .databunch()
#                  .normalize(imagenet_stats))

# %%
data.show_batch(4, figsize=(10,7))

# %%
data.show_batch(4, figsize=(10,7), ds_type=DatasetType.Train)

# %%
data.show_batch(4, figsize=(10,7), ds_type=DatasetType.Valid)

# %%
len(data.classes)
# Out:
# 102

# %% [markdown]
# ## 3. Model

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate)

# %%
# ¿Cómo es la arquitectura del modelo?
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): Bottleneck(
#         (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
# ...

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 00:25<00:25]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
lr=3e-3

# %%
# Entrenando 10 Epochs
learn.fit_one_cycle(10, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.106886</td>
#       <td>2.300998</td>
#       <td>0.546078</td>
#       <td>00:33</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.744085</td>
#       <td>1.135843</td>
#       <td>0.289216</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.574779</td>
#       <td>0.838038</td>
#       <td>0.231373</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.921529</td>
#       <td>0.730499</td>
#       <td>0.193137</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.534882</td>
#       <td>0.560776</td>
#       <td>0.166667</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1')

# %%
learn.show_results(rows=8, figsize=(15,18))

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.most_confused(min_val=2)
# Out:
# [(' desert-rose', ' ruby-lipped cattleya', 2),
#  (' mallow', ' hibiscus', 2),
#  (' morning glory', ' stemless gentian', 2)]

# %%
# learn.load('stage-1')
# learn.unfreeze()
# lrs = slice(lr/400,lr/4)
# learn.fit_one_cycle(12, lrs)
# learn.save('stage-2');

# %% [markdown]
# ## Predict the results for a single image

# %%
# !wget -O image https://lh3.googleusercontent.com/proxy/Ko63UUYxD0a0eRZNhrHOP3xCQQhe8Zl43xa4oQd4QYXtxM1leZApf55l8S1fPS9Vap3j-ndh6U5j1xxb1hrPkHsA99WhmqqX1wa9Oc3ow9b2HQYLZUU2U0E
img = open_image('image')
print('\033[1m' + str(learn.predict(img)[0]).upper() + '\033[0m')
# Out:
# --2020-05-01 11:37:22--  https://lh3.googleusercontent.com/proxy/Ko63UUYxD0a0eRZNhrHOP3xCQQhe8Zl43xa4oQd4QYXtxM1leZApf55l8S1fPS9Vap3j-ndh6U5j1xxb1hrPkHsA99WhmqqX1wa9Oc3ow9b2HQYLZUU2U0E
# Resolving lh3.googleusercontent.com (lh3.googleusercontent.com)... 74.125.142.132, 2607:f8b0:400e:c08::84
# Connecting to lh3.googleusercontent.com (lh3.googleusercontent.com)|74.125.142.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53108 (52K) [image/jpeg]
# Saving to: ‘image’
#
# image               100%[===================>]  51.86K  --.-KB/s    in 0.001s
#
# 2020-05-01 11:37:23 (84.6 MB/s) - ‘image’ saved [53108/53108]
#
#  BOLERO DEEP BLUE

# %%
# !wget -O image https://www.jardineriaon.com/wp-content/uploads/2017/07/flor-de-margarita-830x551.jpg
img = open_image('image')
print('\033[1m' + str(learn.predict(img)[0]).upper() + '\033[0m')
# Out:
# --2020-05-01 11:37:49--  https://www.jardineriaon.com/wp-content/uploads/2017/07/flor-de-margarita-830x551.jpg
# Resolving www.jardineriaon.com (www.jardineriaon.com)... 178.255.231.234
# Connecting to www.jardineriaon.com (www.jardineriaon.com)|178.255.231.234|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29340 (29K) [image/jpeg]
# Saving to: ‘image’
#
# image               100%[===================>]  28.65K   185KB/s    in 0.2s
#
# 2020-05-01 11:37:50 (185 KB/s) - ‘image’ saved [29340/29340]
#
#  OXEYE DAISY

# %% [markdown]
# ## 4. Model 2: Bigger Size

# %%
size = src_size
learn = cnn_learner(data, models.resnet50, metrics=error_rate)

# %%
lr_find(learn)
learn.recorder.plot()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 00:22<00:22]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
lr=3e-3

# %%
# Entrenando 10 Epochs
learn.fit_one_cycle(10, slice(lr))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.949685</td>
#       <td>2.336896</td>
#       <td>0.550980</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.633060</td>
#       <td>1.257723</td>
#       <td>0.303922</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.597376</td>
#       <td>0.814171</td>
#       <td>0.212745</td>
#       <td>00:30</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.923788</td>
#       <td>0.707769</td>
#       <td>0.191176</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.540158</td>
#       <td>0.659894</td>
#       <td>0.174510</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...
